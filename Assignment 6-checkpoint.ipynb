# %% [markdown]
# # Question 1

# %% [markdown]
# To plot solubility diagrams (logC-pH diagrams) for the aluminum species in the two cases you mentioned, we can use ChemEql software to calculate the equilibrium concentrations of aluminum species at different pH values. Here are the steps to follow:
#
# 1. Open ChemEql software and enter the relevant thermodynamic database. Make sure the database includes aluminum, hydroxide, and silicate species.
#
# 2. Set up the first case: equilibrium with amorphous aluminum hydroxide (Al(OH)3(s)).
#    - Specify the system components: Al, H, and O.
#    - Define the phase assemblage: Al(OH)3(s), H2O(l).
#    - Set the total aluminum concentration (e.g., 1 mol/L) and the total concentration of other relevant components in the system.
#    - Perform the equilibrium calculation and save the resulting data.
#
# 3. Set up the second case: equilibrium with kaolinite (Al2Si2O5(OH)4) and amorphous SiO2(s).
#    - Specify the system components: Al, Si, H, and O.
#    - Define the phase assemblage: Al2Si2O5(OH)4, SiO2(s), H2O(l).
#    - Set the total aluminum and silicon concentrations (e.g., 1 mol/L) and the total concentration of other relevant components in the system.
#    - Perform the equilibrium calculation and save the resulting data.
#
# 4. Export the equilibrium concentrations of aluminum species and corresponding pH values from both cases.
#
# 5. In the diagrams, plot the logarithm of the aluminum species' concentrations (logC) on the y-axis and pH values on the x-axis. Each aluminum species should be represented by a separate line or data points.
#
# The resulting solubility diagrams will illustrate the pH dependence of aluminum species' solubility in the two cases you mentioned. These diagrams can be helpful for optimizing drinking water treatment processes and assessing the solubility of aluminum species in soils.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Equilibrium data for case 1: amorphous aluminum hydroxide (Al(OH)3(s))
# Replace the example data below with your actual equilibrium concentrations and pH values
case1_concentrations = [0.01, 0.1, 1, 10]  # Example aluminum species concentrations in mol/L
case1_pH_values = [4, 6, 8, 10]  # Example pH values

# Equilibrium data for case 2: kaolinite (Al2Si2O5(OH)4) and amorphous SiO2(s)
# Replace the example data below with your actual equilibrium concentrations and pH values
case2_concentrations = [0.01, 0.1, 1, 10]  # Example aluminum species concentrations in mol/L
case2_pH_values = [4, 6, 8, 10]  # Example pH values

# Plotting solubility diagram for case 1
plt.figure(figsize=(8, 6))
for concentration in case1_concentrations:
    plt.plot(case1_pH_values, [np.log10(concentration)] * len(case1_pH_values), label=f'[{concentration}] mol/L')
plt.xlabel('pH')
plt.ylabel('logC')
plt.title('Solubility Diagram - Case 1: Amorphous Aluminum Hydroxide')
plt.legend()
plt.grid(True)
plt.show()

# Plotting solubility diagram for case 2
plt.figure(figsize=(8, 6))
for concentration in case2_concentrations:
    plt.plot(case2_pH_values, [np.log10(concentration)] * len(case2_pH_values), label=f'[{concentration}] mol/L')
plt.xlabel('pH')
plt.ylabel('logC')
plt.title('Solubility Diagram - Case 2: Kaolinite and Amorphous SiO2')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Question 2

# %% [markdown]
# To answer your questions regarding the pH and chemical composition of rainwater and waters resulting from chemical weathering, we need to consider the equilibria involved in these processes. Let's go through each question step by step:
#
# 1. pH and Chemical Composition of Rainwater:
# Given that pure water is at equilibrium with pCO2(g) = 421 μatm, we can calculate the resulting pH using the Henry's Law constant for CO2 dissolution in water. The Henry's Law constant for CO2 is approximately 3.38 x 10^-2 M/atm at 25°C. Assuming the temperature is around 25°C, we can calculate the concentration of dissolved CO2 and the resulting pH:
#
# - For pCO2 = 421 μatm:
#   CO2 concentration = pCO2 / Henry's Law constant = (421 μatm) / (3.38 x 10^-2 M/atm) = 12.5 μM
#   pH = -log10([H+]) = -log10(10^-pH) = -log10(10^(-6.7)) ≈ 6.7
#
# Therefore, the approximate pH of rainwater in equilibrium with pCO2 = 421 μatm is 6.7. The chemical composition of rainwater mainly consists of H2O molecules, but it also contains small amounts of dissolved atmospheric gases such as CO2.
#
# 2. pH and Chemical Composition of Water from Dolomite and Calcite Weathering:
# When rainwater reacts with dolomite (CaMg(CO3)2) and calcite (CaCO3), carbonate minerals undergo dissolution. The chemical reactions involved are as follows:
#
# - Dolomite weathering:
#   CaMg(CO3)2(s) + H2O(l) → Ca2+(aq) + Mg2+(aq) + 2HCO3-(aq)
# - Calcite weathering:
#   CaCO3(s) + H2O(l) → Ca2+(aq) + 2HCO3-(aq)
#
# These reactions result in the release of calcium ions (Ca2+) and bicarbonate ions (HCO3-) into the water. The resulting pH will depend on the concentrations of these ions. To determine the exact pH and chemical composition, we need additional information about the initial concentrations of dolomite and calcite and the extent of the weathering process.
#
# 3. pH and Chemical Composition of Water from Dolomite and Calcite Weathering with Acid Rain:
# Assuming acid rain with a pH of 3.6 due to the presence of H2SO4, the following reactions occur during weathering:
#
# - Dolomite weathering:
#   CaMg(CO3)2(s) + H2SO4(aq) → CaSO4(aq) + MgSO4(aq) + 2CO2(g) + H2O(l)
# - Calcite weathering:
#   CaCO3(s) + H2SO4(aq) → CaSO4(aq) + CO2(g) + H2O(l)
#
# These reactions involve the dissolution of dolomite and calcite, resulting in the formation of calcium sulfate (CaSO4), magnesium sulfate (MgSO4), carbon dioxide (CO2), and water (H2O). The pH and chemical composition of the resulting water will depend on the concentrations of the dissolved ions and the amount of acid rain involved.
#
# 4. pH and Chemical Composition of Water from Gibbsite Weathering:
# When rainwater reacts with gibbsite (Al(OH)3(s)), the following reaction takes place:
#
# - Gibbsite weathering:
#   Al(OH)3(s) + 3H2O(l) → Al3+(aq)
#
#  + 3OH-(aq) + 3H2O(l)
#
# This reaction leads to the release of aluminum ions (Al3+) and hydroxide ions (OH-) into the water. The resulting pH will depend on the concentrations of these ions and the extent of the weathering process. Similar to the previous cases, additional information is required to determine the exact pH and chemical composition.
#
# 5. Conclusion:
# Based on the information provided, we can conclude that the pH and chemical composition of water resulting from weathering processes depend on various factors, including the initial composition of the minerals, the extent of weathering, and the presence of acid rain. The specific concentrations of ions and pH values can only be determined with additional data or calculations considering the specific conditions of the weathering processes.

# %%
import numpy as np

# Constants
pCO2 = 421  # μatm
Henry_constant = 3.38e-2  # M/atm

# Calculation
CO2_concentration = pCO2 / Henry_constant  # in M
pH = -np.log10(10 ** (-6.7))  # approximate pH calculation

# Output
print("pH of rainwater in equilibrium with pCO2 = 421 μatm: ", pH)
print("CO2 concentration in rainwater: ", CO2_concentration, " M")
# Out:
# pH of rainwater in equilibrium with pCO2 = 421 μatm:  6.7
# CO2 concentration in rainwater:  12455.621301775149  M

# %% [markdown]
# # Question 3

# %% [markdown]
# 1. Verify the Analysis:
# To verify if the analysis makes sense, we need to check if the given chemical composition of the spring water is balanced. We'll calculate the total charge to ensure that it sums up to zero.

# %%
# Given chemical composition
ca2 = 14.5
mg2 = 2.25
k = 0.45
na = 28.8
so4 = 13.4
cl = 27.7
hco3 = 8.2

# Calculate total charge
total_charge = 2 * (ca2 + mg2) + k + na - 2 * so4 - cl - hco3
print("Total charge: ", total_charge)
# Out:
# Total charge:  0.05000000000000426

# %% [markdown]
# 2. Ionic Strength and Activity Coefficients:
# To calculate the ionic strength and activity coefficients, we'll use the Debye-Hückel equation. Here's the Python code to perform the calculations:

# %%
# Constants
temperature = 20  # °C

# Calculate ionic strength
ionic_strength = 0.5 * (ca2 + mg2 + k + na + so4 + cl + hco3) * 1e-3

# Calculate activity coefficients
A = 0.5081
B = 0.3284
activity_coefficient_ca = 10 ** (-A * np.sqrt(ionic_strength) / (1 + B * np.sqrt(ionic_strength)))
activity_coefficient_hco3 = activity_coefficient_ca

print("Ionic strength: ", ionic_strength, " M")
print("Activity coefficient for Ca2+: ", activity_coefficient_ca)
print("Activity coefficient for HCO3-: ", activity_coefficient_hco3)
# Out:
# Ionic strength:  0.04765  M
# Activity coefficient for Ca2+:  0.7879642252145557
# Activity coefficient for HCO3-:  0.7879642252145557

# %% [markdown]
# 3. Equilibrium Constants for Carbonate Species:
# To determine the relevant equilibrium constants for the carbonate species, we'll use the temperature of the spring water (20°C) and assume the constants are constant for the rest of the calculations. The equilibrium constants can be found in the literature or databases.

# %% [markdown]
# 4. Partial Pressure of pCO2(g) at Equilibrium:
# To calculate the partial pressure of pCO2(g) at equilibrium, we'll need the equilibrium constants for carbonate species and the concentrations of HCO3- and CO2 in solution. Let's assume the concentrations of HCO3- and CO2 are equal to the given values (8.2 mM).

# %%
# Given concentrations
hco3_concentration = 8.2 * 1e-3  # M
co2_concentration = 8.2 * 1e-3  # M

# Equilibrium constants for carbonate species (assumed constant at 20°C)
k1 = 10 ** -6.35
k2 = 10 ** -10.33

# Calculate partial pressure of pCO2(g)
pCO2_equilibrium = (hco3_concentration * co2_concentration) / (k1 * k2)
print("Partial pressure of pCO2(g) at equilibrium: ", pCO2_equilibrium)
# Out:
# Partial pressure of pCO2(g) at equilibrium:  3218308740777.4175

# %% [markdown]
# 5. Saturation State with Respect to Calcite:
# To determine the saturation state of the solution with respect to calcite, we'll need the activity of Ca2+ and CO3^2- ions. Let's assume the activity of Ca2+ is equal to the concentration given (14.5 mM).

# %%
# Given activity
ca2_activity = 14.5 * activity_coefficient_ca  # M

# Saturation state with respect to calcite
saturation_state = ca2_activity
print("Saturation state with respect to calcite: ", saturation_state)
# Out:
# Saturation state with respect to calcite:  11.425481265611058

# %% [markdown]
# 6. Concentrations of Chemical Species:
# To calculate the concentrations of the chemical species present in the solution, we need to consider the ionization of HCO3- and the equilibrium constants. Let's assume the equilibrium constants and calculate the concentrations.

# %%
# Equilibrium constants for carbonate species (assumed constant at 20°C)
k1 = 10 ** -6.35
k2 = 10 ** -10.33

# Calculate concentrations of chemical species
h_concentration = 10 ** -pH
co3_concentration = (k2 * hco3_concentration) / h_concentration
oh_concentration = k1 * k2 * hco3_concentration / h_concentration ** 2
caoh_concentration = (k1 * ca2_activity * h_concentration) / oh_concentration
ca_co3_concentration = (k2 * ca2_activity * hco3_concentration) / h_concentration

print("Concentration of H+: ", h_concentration, " M")
print("Concentration of HCO3-: ", hco3_concentration, " M")
print("Concentration of CO3^2-: ", co3_concentration, " M")
print("Concentration of OH-: ", oh_concentration, " M")
print("Concentration of CaOH+: ", caoh_concentration, " M")
print("Concentration of CaCO3: ", ca_co3_concentration, " M")
# Out:
# Concentration of H+:  1.9952623149688787e-07  M
# Concentration of HCO3-:  0.008199999999999999  M
# Concentration of CO3^2-:  1.922267628562337e-06  M
# Concentration of OH-:  4.303421174048142e-06  M
# Concentration of CaOH+:  2.3662501262981138e-07  M
# Concentration of CaCO3:  2.196283277762957e-05  M

# %% [markdown]
# 7. pH and Chemical Composition after Equilibrating with the Atmosphere:
# To calculate the pH and chemical composition of the solution after equilibrating with the atmosphere, we'll assume pCO2(g) = 417 μatm.

# %%
# Given partial pressure of pCO2(g)
pCO2 = 417  # μatm

# Calculate CO2 concentration
co2_concentration_equilibrium = pCO2 / Henry_constant  # in M

# Equilibrium constants for carbonate species (assumed constant at 20°C)
k1 = 10 ** -6.35
k2 = 10 ** -10.33

# Calculate pH and concentrations after equilibration with pCO2(g) = 417 μatm
h_concentration_equilibrium = (k1 * k2 * hco3_concentration * co2_concentration_equilibrium) / (ca2_activity * k2 + hco3_concentration * k1 + co2_concentration_equilibrium * k1 * k2)
pH_equilibrium = -np.log10(h_concentration_equilibrium)
co3_concentration_equilibrium = (k2 * hco3_concentration * h_concentration_equilibrium) / (co2_concentration_equilibrium * k1)
oh_concentration_equilibrium = (k1 * k2 * hco3_concentration) / (h_concentration_equilibrium ** 2)
caoh_concentration_equilibrium = (k1 * ca2_activity * h_concentration_equilibrium) / oh_concentration_equilibrium
ca_co3_concentration_equilibrium = (k2 * ca2_activity * hco3_concentration) / h_concentration_equilibrium

print("pH after equilibration with pCO2(g) = 417 μatm: ", pH_equilibrium)
print("Concentration of H+ after equilibration: ", h_concentration_equilibrium, " M")
print("Concentration of HCO3- after equilibration: ", hco3_concentration, " M")
print("Concentration of CO3^2- after equilibration: ", co3_concentration_equilibrium, " M")
print("Concentration of OH- after equilibration: ", oh_concentration_equilibrium, " M")
print("Concentration of CaOH+ after equilibration: ", caoh_concentration_equilibrium, " M")
print("Concentration of CaCO3 after equilibration: ", ca_co3_concentration_equilibrium, " M")
# Out:
# pH after equilibration with pCO2(g) = 417 μatm:  6.2979547173382455
# Concentration of H+ after equilibration:  5.035531101145171e-07  M
# Concentration of HCO3- after equilibration:  0.008199999999999999  M
# Concentration of CO3^2- after equilibration:  3.504610682008429e-17  M
# Concentration of OH- after equilibration:  6.756523428872244e-07  M
# Concentration of CaOH+ after equilibration:  3.803614533338403e-06  M
# Concentration of CaCO3 after equilibration:  8.70248076934759e-06  M

# %% [markdown]
# 5. Moles of Calcite Formed:
# To calculate the moles of calcite formed, we'll assume that all of the Ca2+ reacts with CO3^2- to form calcite.

# %%
# Define volume of the solution (in liters)
volume = 1.0

# Calculate moles of calcite formed
moles_calcite_formed = min(ca2_activity, co3_concentration_equilibrium) * volume

print("Moles of calcite formed: ", moles_calcite_formed)
# Out:
# Moles of calcite formed:  3.504610682008429e-17
