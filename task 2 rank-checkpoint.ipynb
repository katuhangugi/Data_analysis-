# %%
import os
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.tokenize import sent_tokenize


def get_sentences_from_document(filepath):
    with open(filepath, 'r') as file:
        document = file.read()
    sentences = sent_tokenize(document)
    return sentences


def get_document_embedding(sentences):
    model = SentenceTransformer('bert-base-nli-mean-tokens')
    sentence_embeddings = model.encode(sentences)
    document_embedding = np.mean(sentence_embeddings, axis=0)
    return document_embedding


def rank_documents(query_embedding, document_embeddings, documents, k):
    similarities = cosine_similarity(query_embedding.reshape(1, -1), document_embeddings)[0]
    ranked_indices = np.argsort(-similarities)[:k]
    ranked_documents = [documents[i] for i in ranked_indices]
    return ranked_documents


def process_query_case(query_case_filepath, corpus_folder, k, batch_size=50):
    query_sentences = get_sentences_from_document(query_case_filepath)
    query_embedding = get_document_embedding(query_sentences)

    document_embeddings = []
    documents = []

    for document_file in os.listdir(corpus_folder):
        document_filepath = os.path.join(corpus_folder, document_file)
        document_sentences = get_sentences_from_document(document_filepath)
        document_embedding = get_document_embedding(document_sentences)
        document_embeddings.append(document_embedding)
        documents.append(document_file)

        if len(document_embeddings) == batch_size:
            document_embeddings = np.vstack(document_embeddings)
            ranked_documents = rank_documents(query_embedding, document_embeddings, documents, k)
            document_embeddings = []
            documents = []

            yield ranked_documents

    if len(document_embeddings) > 0:
        document_embeddings = np.vstack(document_embeddings)
        ranked_documents = rank_documents(query_embedding, document_embeddings, documents, k)

        yield ranked_documents


def main():
    query_case_filepath = r"C:\Users\This PC\Desktop\Task_2\Prior_Cases\prior_case_0001.txt"
    corpus_folder = r"C:\Users\This PC\Desktop\Task_2\Prior_Cases"
    k = 100  # Number of top-ranked documents to retrieve
    batch_size = 50  # Batch size for processing documents

    batch_generator = process_query_case(query_case_filepath, corpus_folder, k, batch_size)

    for i, ranked_documents in enumerate(batch_generator):
        print(f"Batch {i+1} - Ranked Documents:")
        for j, document in enumerate(ranked_documents):
            print(f"Rank {j+1}: {document}")
        print()

if __name__ == '__main__':
    main()
# Out:
# Batch 1 - Ranked Documents:
# Rank 1: prior_case_0001.txt
# Rank 2: prior_case_0045.txt
# Rank 3: prior_case_0037.txt
# Rank 4: prior_case_0011.txt
# Rank 5: prior_case_0031.txt
# Rank 6: prior_case_0050.txt
# Rank 7: prior_case_0030.txt
# Rank 8: prior_case_0039.txt
# Rank 9: prior_case_0015.txt
# Rank 10: prior_case_0004.txt
# Rank 11: prior_case_0043.txt
# Rank 12: prior_case_0042.txt
# Rank 13: prior_case_0025.txt
# Rank 14: prior_case_0023.txt
# Rank 15: prior_case_0033.txt
# Rank 16: prior_case_0028.txt
# Rank 17: prior_case_0021.txt
# Rank 18: prior_case_0008.txt
# Rank 19: prior_case_0036.txt
# Rank 20: prior_case_0027.txt
# Rank 21: prior_case_0009.txt
# Rank 22: prior_case_0003.txt
# Rank 23: prior_case_0020.txt
# Rank 24: prior_case_0049.txt
# Rank 25: prior_case_0017.txt
# Rank 26: prior_case_0010.txt
# Rank 27: prior_case_0048.txt
# Rank 28: prior_case_0012.txt
# Rank 29: prior_case_0002.txt
# Rank 30: prior_case_0016.txt
# Rank 31: prior_case_0006.txt
# Rank 32: prior_case_0035.txt
# Rank 33: prior_case_0014.txt
# Rank 34: prior_case_0038.txt
# Rank 35: prior_case_0018.txt
# Rank 36: prior_case_0046.txt
# Rank 37: prior_case_0034.txt
# Rank 38: prior_case_0041.txt
# Rank 39: prior_case_0044.txt
# Rank 40: prior_case_0047.txt
# Rank 41: prior_case_0007.txt
# Rank 42: prior_case_0019.txt
# Rank 43: prior_case_0005.txt
# Rank 44: prior_case_0032.txt
# Rank 45: prior_case_0024.txt
# Rank 46: prior_case_0029.txt
# Rank 47: prior_case_0040.txt
# Rank 48: prior_case_0013.txt
# Rank 49: prior_case_0026.txt
# Rank 50: prior_case_0022.txt
#
# Batch 2 - Ranked Documents:
# Rank 1: prior_case_0084.txt
# Rank 2: prior_case_0054.txt
# Rank 3: prior_case_0058.txt
# Rank 4: prior_case_0059.txt
# Rank 5: prior_case_0076.txt
# Rank 6: prior_case_0079.txt
# Rank 7: prior_case_0100.txt
# Rank 8: prior_case_0069.txt
# Rank 9: prior_case_0078.txt
# Rank 10: prior_case_0093.txt
# Rank 11: prior_case_0061.txt
# Rank 12: prior_case_0056.txt
# Rank 13: prior_case_0080.txt
# Rank 14: prior_case_0067.txt
# Rank 15: prior_case_0051.txt
# Rank 16: prior_case_0070.txt
# Rank 17: prior_case_0062.txt
# Rank 18: prior_case_0087.txt
# Rank 19: prior_case_0092.txt
# Rank 20: prior_case_0075.txt
# Rank 21: prior_case_0065.txt
# Rank 22: prior_case_0094.txt
# Rank 23: prior_case_0086.txt
# Rank 24: prior_case_0053.txt
# Rank 25: prior_case_0052.txt
# Rank 26: prior_case_0099.txt
# Rank 27: prior_case_0064.txt
# Rank 28: prior_case_0073.txt
# Rank 29: prior_case_0063.txt
# Rank 30: prior_case_0095.txt
# Rank 31: prior_case_0055.txt
# Rank 32: prior_case_0057.txt
# Rank 33: prior_case_0082.txt
# Rank 34: prior_case_0081.txt
# Rank 35: prior_case_0060.txt
# Rank 36: prior_case_0096.txt
# Rank 37: prior_case_0090.txt
# Rank 38: prior_case_0066.txt
# Rank 39: prior_case_0068.txt
# Rank 40: prior_case_0072.txt
# Rank 41: prior_case_0098.txt
# Rank 42: prior_case_0089.txt
# Rank 43: prior_case_0085.txt
# Rank 44: prior_case_0083.txt
# Rank 45: prior_case_0074.txt
# Rank 46: prior_case_0077.txt
# Rank 47: prior_case_0071.txt
# Rank 48: prior_case_0091.txt
# Rank 49: prior_case_0097.txt
# Rank 50: prior_case_0088.txt
#
# Batch 3 - Ranked Documents:
# Rank 1: prior_case_0110.txt
# Rank 2: prior_case_0150.txt
# Rank 3: prior_case_0132.txt
# Rank 4: prior_case_0134.txt
# Rank 5: prior_case_0109.txt
# Rank 6: prior_case_0149.txt
# Rank 7: prior_case_0143.txt
# Rank 8: prior_case_0106.txt
# Rank 9: prior_case_0112.txt
# Rank 10: prior_case_0115.txt
# Rank 11: prior_case_0122.txt
# Rank 12: prior_case_0126.txt
# Rank 13: prior_case_0108.txt
# Rank 14: prior_case_0103.txt
# Rank 15: prior_case_0136.txt
# Rank 16: prior_case_0139.txt
# Rank 17: prior_case_0114.txt
# Rank 18: prior_case_0104.txt
# Rank 19: prior_case_0146.txt
# Rank 20: prior_case_0118.txt
# Rank 21: prior_case_0120.txt
# Rank 22: prior_case_0129.txt
# Rank 23: prior_case_0145.txt
# Rank 24: prior_case_0142.txt
# Rank 25: prior_case_0135.txt
# Rank 26: prior_case_0102.txt
# Rank 27: prior_case_0130.txt
# Rank 28: prior_case_0140.txt
# Rank 29: prior_case_0121.txt
# Rank 30: prior_case_0144.txt
# Rank 31: prior_case_0127.txt
# Rank 32: prior_case_0131.txt
# Rank 33: prior_case_0128.txt
# Rank 34: prior_case_0111.txt
# Rank 35: prior_case_0117.txt
# Rank 36: prior_case_0107.txt
# Rank 37: prior_case_0138.txt
# Rank 38: prior_case_0147.txt
# Rank 39: prior_case_0101.txt
# Rank 40: prior_case_0148.txt
# Rank 41: prior_case_0137.txt
# Rank 42: prior_case_0124.txt
# Rank 43: prior_case_0119.txt
# Rank 44: prior_case_0113.txt
# Rank 45: prior_case_0123.txt
# Rank 46: prior_case_0133.txt
# Rank 47: prior_case_0125.txt
# Rank 48: prior_case_0105.txt
# Rank 49: prior_case_0116.txt
# Rank 50: prior_case_0141.txt
#
# Batch 4 - Ranked Documents:
# Rank 1: prior_case_0153.txt
# Rank 2: prior_case_0168.txt
# Rank 3: prior_case_0182.txt
# Rank 4: prior_case_0152.txt
# Rank 5: prior_case_0177.txt
# Rank 6: prior_case_0163.txt
# Rank 7: prior_case_0180.txt
# Rank 8: prior_case_0198.txt
# Rank 9: prior_case_0185.txt
# Rank 10: prior_case_0192.txt
# Rank 11: prior_case_0193.txt
# Rank 12: prior_case_0186.txt
# Rank 13: prior_case_0196.txt
# Rank 14: prior_case_0179.txt
# Rank 15: prior_case_0172.txt
# Rank 16: prior_case_0166.txt
# Rank 17: prior_case_0187.txt
# Rank 18: prior_case_0162.txt
# Rank 19: prior_case_0174.txt
# Rank 20: prior_case_0158.txt
# Rank 21: prior_case_0154.txt
# Rank 22: prior_case_0200.txt
# Rank 23: prior_case_0155.txt
# Rank 24: prior_case_0183.txt
# Rank 25: prior_case_0159.txt
# Rank 26: prior_case_0169.txt
# Rank 27: prior_case_0190.txt
# Rank 28: prior_case_0161.txt
# Rank 29: prior_case_0181.txt
# Rank 30: prior_case_0197.txt
# Rank 31: prior_case_0189.txt
# Rank 32: prior_case_0173.txt
# Rank 33: prior_case_0165.txt
# Rank 34: prior_case_0199.txt
# Rank 35: prior_case_0164.txt
# Rank 36: prior_case_0175.txt
# Rank 37: prior_case_0184.txt
# Rank 38: prior_case_0194.txt
# Rank 39: prior_case_0191.txt
# Rank 40: prior_case_0176.txt
# Rank 41: prior_case_0157.txt
# Rank 42: prior_case_0195.txt
# Rank 43: prior_case_0171.txt
# Rank 44: prior_case_0151.txt
# Rank 45: prior_case_0167.txt
# Rank 46: prior_case_0160.txt
# Rank 47: prior_case_0188.txt
# Rank 48: prior_case_0170.txt
# Rank 49: prior_case_0178.txt
# Rank 50: prior_case_0156.txt
