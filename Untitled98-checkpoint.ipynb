# %%
import os
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.tokenize import sent_tokenize


def get_sentences_from_document(filepath):
    with open(filepath, 'r') as file:
        document = file.read()
    sentences = sent_tokenize(document)
    return sentences


def get_document_embedding(sentences):
    model = SentenceTransformer('bert-base-nli-mean-tokens')
    sentence_embeddings = model.encode(sentences)
    document_embedding = np.mean(sentence_embeddings, axis=0)
    return document_embedding


def rank_documents(query_embedding, document_embeddings, documents, k):
    similarities = cosine_similarity(query_embedding.reshape(1, -1), document_embeddings)[0]
    ranked_indices = np.argsort(-similarities)[:k]
    ranked_documents = [documents[i] for i in ranked_indices]
    return ranked_documents


def process_query_case(query_case_filepath, corpus_folder, k, batch_size=50):
    query_sentences = get_sentences_from_document(query_case_filepath)
    query_embedding = get_document_embedding(query_sentences)

    document_embeddings = []
    documents = []

    for document_file in os.listdir(corpus_folder):
        document_filepath = os.path.join(corpus_folder, document_file)
        document_sentences = get_sentences_from_document(document_filepath)
        document_embedding = get_document_embedding(document_sentences)
        document_embeddings.append(document_embedding)
        documents.append(document_file)

        if len(document_embeddings) == batch_size:
            document_embeddings = np.vstack(document_embeddings)
            ranked_documents = rank_documents(query_embedding, document_embeddings, documents, k)
            document_embeddings = []
            documents = []

            yield ranked_documents

    if len(document_embeddings) > 0:
        document_embeddings = np.vstack(document_embeddings)
        ranked_documents = rank_documents(query_embedding, document_embeddings, documents, k)

        yield ranked_documents


def main():
    query_case_filepath = r"C:\Users\This PC\Desktop\Task_1\Test_catches\case_100_catchwords.txt"
    corpus_folder = r"C:\Users\This PC\Desktop\Task_1\Test_catches"
    k = 100  # Number of top-ranked documents to retrieve
    batch_size = 50  # Batch size for processing documents

    batch_generator = process_query_case(query_case_filepath, corpus_folder, k, batch_size)

    for i, ranked_documents in enumerate(batch_generator):
        print(f"Batch {i+1} - Ranked Documents:")
        for j, document in enumerate(ranked_documents):
            print(f"Rank {j+1}: {document}")
        print()

if __name__ == '__main__':
    main()
# Out:
# Batch 1 - Ranked Documents:
# Rank 1: case_100_catchwords.txt
# Rank 2: case_107_catchwords.txt
# Rank 3: case_141_catchwords.txt
# Rank 4: case_102_catchwords.txt
# Rank 5: case_131_catchwords.txt
# Rank 6: case_114_catchwords.txt
# Rank 7: case_143_catchwords.txt
# Rank 8: case_106_catchwords.txt
# Rank 9: case_145_catchwords.txt
# Rank 10: case_129_catchwords.txt
# Rank 11: case_127_catchwords.txt
# Rank 12: case_115_catchwords.txt
# Rank 13: case_110_catchwords.txt
# Rank 14: case_137_catchwords.txt
# Rank 15: case_146_catchwords.txt
# Rank 16: case_132_catchwords.txt
# Rank 17: case_126_catchwords.txt
# Rank 18: case_147_catchwords.txt
# Rank 19: case_101_catchwords.txt
# Rank 20: case_120_catchwords.txt
# Rank 21: case_135_catchwords.txt
# Rank 22: case_118_catchwords.txt
# Rank 23: case_134_catchwords.txt
# Rank 24: case_148_catchwords.txt
# Rank 25: case_130_catchwords.txt
# Rank 26: case_133_catchwords.txt
# Rank 27: case_136_catchwords.txt
# Rank 28: case_109_catchwords.txt
# Rank 29: case_105_catchwords.txt
# Rank 30: case_121_catchwords.txt
# Rank 31: case_123_catchwords.txt
# Rank 32: case_122_catchwords.txt
# Rank 33: case_119_catchwords.txt
# Rank 34: case_117_catchwords.txt
# Rank 35: case_113_catchwords.txt
# Rank 36: case_142_catchwords.txt
# Rank 37: case_128_catchwords.txt
# Rank 38: case_111_catchwords.txt
# Rank 39: case_124_catchwords.txt
# Rank 40: case_112_catchwords.txt
# Rank 41: case_104_catchwords.txt
# Rank 42: case_144_catchwords.txt
# Rank 43: case_139_catchwords.txt
# Rank 44: case_116_catchwords.txt
# Rank 45: case_138_catchwords.txt
# Rank 46: case_108_catchwords.txt
# Rank 47: case_103_catchwords.txt
# Rank 48: case_149_catchwords.txt
# Rank 49: case_125_catchwords.txt
# Rank 50: case_140_catchwords.txt
#
# Batch 2 - Ranked Documents:
# Rank 1: case_196_catchwords.txt
# Rank 2: case_169_catchwords.txt
# Rank 3: case_180_catchwords.txt
# Rank 4: case_173_catchwords.txt
# Rank 5: case_181_catchwords.txt
# Rank 6: case_176_catchwords.txt
# Rank 7: case_191_catchwords.txt
# Rank 8: case_190_catchwords.txt
# Rank 9: case_188_catchwords.txt
# Rank 10: case_179_catchwords.txt
# Rank 11: case_193_catchwords.txt
# Rank 12: case_154_catchwords.txt
# Rank 13: case_192_catchwords.txt
# Rank 14: case_165_catchwords.txt
# Rank 15: case_166_catchwords.txt
# Rank 16: case_197_catchwords.txt
# Rank 17: case_161_catchwords.txt
# Rank 18: case_163_catchwords.txt
# Rank 19: case_157_catchwords.txt
# Rank 20: case_182_catchwords.txt
# Rank 21: case_178_catchwords.txt
# Rank 22: case_198_catchwords.txt
# Rank 23: case_175_catchwords.txt
# Rank 24: case_184_catchwords.txt
# Rank 25: case_199_catchwords.txt
# Rank 26: case_159_catchwords.txt
# Rank 27: case_160_catchwords.txt
# Rank 28: case_156_catchwords.txt
# Rank 29: case_177_catchwords.txt
# Rank 30: case_186_catchwords.txt
# Rank 31: case_183_catchwords.txt
# Rank 32: case_150_catchwords.txt
# Rank 33: case_158_catchwords.txt
# Rank 34: case_195_catchwords.txt
# Rank 35: case_171_catchwords.txt
# Rank 36: case_185_catchwords.txt
# Rank 37: case_151_catchwords.txt
# Rank 38: case_168_catchwords.txt
# Rank 39: case_194_catchwords.txt
# Rank 40: case_164_catchwords.txt
# Rank 41: case_155_catchwords.txt
# Rank 42: case_153_catchwords.txt
# Rank 43: case_172_catchwords.txt
# Rank 44: case_189_catchwords.txt
# Rank 45: case_174_catchwords.txt
# Rank 46: case_167_catchwords.txt
# Rank 47: case_152_catchwords.txt
# Rank 48: case_162_catchwords.txt
# Rank 49: case_187_catchwords.txt
# Rank 50: case_170_catchwords.txt
#
# Batch 3 - Ranked Documents:
# Rank 1: case_201_catchwords.txt
# Rank 2: case_208_catchwords.txt
# Rank 3: case_224_catchwords.txt
# Rank 4: case_247_catchwords.txt
# Rank 5: case_236_catchwords.txt
# Rank 6: case_204_catchwords.txt
# Rank 7: case_220_catchwords.txt
# Rank 8: case_248_catchwords.txt
# Rank 9: case_246_catchwords.txt
# Rank 10: case_228_catchwords.txt
# Rank 11: case_219_catchwords.txt
# Rank 12: case_202_catchwords.txt
# Rank 13: case_233_catchwords.txt
# Rank 14: case_237_catchwords.txt
# Rank 15: case_214_catchwords.txt
# Rank 16: case_245_catchwords.txt
# Rank 17: case_203_catchwords.txt
# Rank 18: case_243_catchwords.txt
# Rank 19: case_206_catchwords.txt
# Rank 20: case_212_catchwords.txt
# Rank 21: case_231_catchwords.txt
# Rank 22: case_217_catchwords.txt
# Rank 23: case_215_catchwords.txt
# Rank 24: case_209_catchwords.txt
# Rank 25: case_218_catchwords.txt
# Rank 26: case_207_catchwords.txt
# Rank 27: case_244_catchwords.txt
# Rank 28: case_222_catchwords.txt
# Rank 29: case_213_catchwords.txt
# Rank 30: case_223_catchwords.txt
# Rank 31: case_210_catchwords.txt
# Rank 32: case_240_catchwords.txt
# Rank 33: case_229_catchwords.txt
# Rank 34: case_227_catchwords.txt
# Rank 35: case_238_catchwords.txt
# Rank 36: case_226_catchwords.txt
# Rank 37: case_241_catchwords.txt
# Rank 38: case_242_catchwords.txt
# Rank 39: case_225_catchwords.txt
# Rank 40: case_200_catchwords.txt
# Rank 41: case_205_catchwords.txt
# Rank 42: case_232_catchwords.txt
# Rank 43: case_211_catchwords.txt
# Rank 44: case_234_catchwords.txt
# Rank 45: case_249_catchwords.txt
# Rank 46: case_216_catchwords.txt
# Rank 47: case_230_catchwords.txt
# Rank 48: case_239_catchwords.txt
# Rank 49: case_221_catchwords.txt
# Rank 50: case_235_catchwords.txt
#
# Batch 4 - Ranked Documents:
# Rank 1: case_256_catchwords.txt
# Rank 2: case_289_catchwords.txt
# Rank 3: case_298_catchwords.txt
# Rank 4: case_265_catchwords.txt
# Rank 5: case_282_catchwords.txt
# Rank 6: case_299_catchwords.txt
# Rank 7: case_257_catchwords.txt
# Rank 8: case_258_catchwords.txt
# Rank 9: case_269_catchwords.txt
# Rank 10: case_276_catchwords.txt
# Rank 11: case_261_catchwords.txt
# Rank 12: case_273_catchwords.txt
# Rank 13: case_294_catchwords.txt
# Rank 14: case_266_catchwords.txt
# Rank 15: case_291_catchwords.txt
# Rank 16: case_280_catchwords.txt
# Rank 17: case_275_catchwords.txt
# Rank 18: case_297_catchwords.txt
# Rank 19: case_263_catchwords.txt
# Rank 20: case_295_catchwords.txt
# Rank 21: case_279_catchwords.txt
# Rank 22: case_272_catchwords.txt
# Rank 23: case_293_catchwords.txt
# Rank 24: case_281_catchwords.txt
# Rank 25: case_250_catchwords.txt
# Rank 26: case_288_catchwords.txt
# Rank 27: case_271_catchwords.txt
# Rank 28: case_286_catchwords.txt
# Rank 29: case_260_catchwords.txt
# Rank 30: case_270_catchwords.txt
# Rank 31: case_255_catchwords.txt
# Rank 32: case_296_catchwords.txt
# Rank 33: case_259_catchwords.txt
# Rank 34: case_277_catchwords.txt
# Rank 35: case_264_catchwords.txt
# Rank 36: case_262_catchwords.txt
# Rank 37: case_285_catchwords.txt
# Rank 38: case_283_catchwords.txt
# Rank 39: case_253_catchwords.txt
# Rank 40: case_284_catchwords.txt
# Rank 41: case_251_catchwords.txt
# Rank 42: case_287_catchwords.txt
# Rank 43: case_252_catchwords.txt
# Rank 44: case_278_catchwords.txt
# Rank 45: case_290_catchwords.txt
# Rank 46: case_274_catchwords.txt
# Rank 47: case_254_catchwords.txt
# Rank 48: case_292_catchwords.txt
# Rank 49: case_268_catchwords.txt
# Rank 50: case_267_catchwords.txt
#
# Batch 5 - Ranked Documents:
# Rank 1: case_317_catchwords.txt
# Rank 2: case_304_catchwords.txt
# Rank 3: case_311_catchwords.txt
# Rank 4: case_342_catchwords.txt
# Rank 5: case_331_catchwords.txt
# Rank 6: case_310_catchwords.txt
# Rank 7: case_313_catchwords.txt
# Rank 8: case_318_catchwords.txt
# Rank 9: case_334_catchwords.txt
# Rank 10: case_302_catchwords.txt
# Rank 11: case_341_catchwords.txt
# Rank 12: case_325_catchwords.txt
# Rank 13: case_336_catchwords.txt
# Rank 14: case_316_catchwords.txt
# Rank 15: case_305_catchwords.txt
# Rank 16: case_335_catchwords.txt
# Rank 17: case_301_catchwords.txt
# Rank 18: case_315_catchwords.txt
# Rank 19: case_332_catchwords.txt
# Rank 20: case_314_catchwords.txt
# Rank 21: case_303_catchwords.txt
# Rank 22: case_340_catchwords.txt
# Rank 23: case_337_catchwords.txt
# Rank 24: case_333_catchwords.txt
# Rank 25: case_320_catchwords.txt
# Rank 26: case_346_catchwords.txt
# Rank 27: case_343_catchwords.txt
# Rank 28: case_328_catchwords.txt
# Rank 29: case_321_catchwords.txt
# Rank 30: case_345_catchwords.txt
# Rank 31: case_312_catchwords.txt
# Rank 32: case_322_catchwords.txt
# Rank 33: case_307_catchwords.txt
# Rank 34: case_323_catchwords.txt
# Rank 35: case_327_catchwords.txt
# Rank 36: case_309_catchwords.txt
# Rank 37: case_347_catchwords.txt
# Rank 38: case_339_catchwords.txt
# Rank 39: case_330_catchwords.txt
# Rank 40: case_338_catchwords.txt
# Rank 41: case_344_catchwords.txt
# Rank 42: case_308_catchwords.txt
# Rank 43: case_326_catchwords.txt
# Rank 44: case_324_catchwords.txt
# Rank 45: case_319_catchwords.txt
# Rank 46: case_329_catchwords.txt
# Rank 47: case_300_catchwords.txt
# Rank 48: case_349_catchwords.txt
# Rank 49: case_348_catchwords.txt
# Rank 50: case_306_catchwords.txt
# Batch 6 - Ranked Documents:
# Rank 1: case_364_catchwords.txt
# Rank 2: case_382_catchwords.txt
# Rank 3: case_359_catchwords.txt
# Rank 4: case_369_catchwords.txt
# Rank 5: case_379_catchwords.txt
# Rank 6: case_355_catchwords.txt
# Rank 7: case_358_catchwords.txt
# Rank 8: case_380_catchwords.txt
# Rank 9: case_350_catchwords.txt
# Rank 10: case_376_catchwords.txt
# Rank 11: case_365_catchwords.txt
# Rank 12: case_373_catchwords.txt
# Rank 13: case_367_catchwords.txt
# Rank 14: case_353_catchwords.txt
# Rank 15: case_384_catchwords.txt
# Rank 16: case_370_catchwords.txt
# Rank 17: case_351_catchwords.txt
# Rank 18: case_385_catchwords.txt
# Rank 19: case_360_catchwords.txt
# Rank 20: case_362_catchwords.txt
# Rank 21: case_388_catchwords.txt
# Rank 22: case_377_catchwords.txt
# Rank 23: case_366_catchwords.txt
# Rank 24: case_391_catchwords.txt
# Rank 25: case_375_catchwords.txt
# Rank 26: case_371_catchwords.txt
# Rank 27: case_386_catchwords.txt
# Rank 28: case_361_catchwords.txt
# Rank 29: case_378_catchwords.txt
# Rank 30: case_383_catchwords.txt
# Rank 31: case_389_catchwords.txt
# Rank 32: case_395_catchwords.txt
# Rank 33: case_393_catchwords.txt
# Rank 34: case_368_catchwords.txt
# Rank 35: case_397_catchwords.txt
# Rank 36: case_352_catchwords.txt
# Rank 37: case_374_catchwords.txt
# Rank 38: case_372_catchwords.txt
# Rank 39: case_363_catchwords.txt
# Rank 40: case_399_catchwords.txt
# Rank 41: case_392_catchwords.txt
# Rank 42: case_356_catchwords.txt
# Rank 43: case_387_catchwords.txt
# Rank 44: case_390_catchwords.txt
# Rank 45: case_398_catchwords.txt
# Rank 46: case_394_catchwords.txt
# Rank 47: case_381_catchwords.txt
# Rank 48: case_396_catchwords.txt
# Rank 49: case_354_catchwords.txt
# Rank 50: case_357_catchwords.txt
