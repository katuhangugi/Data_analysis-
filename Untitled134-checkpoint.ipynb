# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import pymc3 as pm

# Step 1: Data Cleaning and Visualization
data = pd.read_excel('C://Users//This PC//Downloads//data.xlsx')
data = data.drop(data.index[-1])  # Remove the last row

# Scatter plots to visualize the relationship between LSH and other variables
fig, axs = plt.subplots(2, 2, figsize=(10, 8))
axs[0, 0].scatter(data['LSH'], data['YR'])
axs[0, 0].set_xlabel('LSH')
axs[0, 0].set_ylabel('YR')

axs[0, 1].scatter(data['LSH'], data['AA'])
axs[0, 1].set_xlabel('LSH')
axs[0, 1].set_ylabel('AA')

axs[1, 0].scatter(data['LSH'], data['CCF'])
axs[1, 0].set_xlabel('LSH')
axs[1, 0].set_ylabel('CCF')

axs[1, 1].scatter(data['LSH'], data['TPAM'])
axs[1, 1].set_xlabel('LSH')
axs[1, 1].set_ylabel('TPAM')

plt.tight_layout()
plt.show()

# Step 2: Likelihood Function or Loss Function
# Define the specific likelihood or loss function based on your modeling approach.

# Step 3: Estimation of Model Parameters and Optimization
# For this example, let's perform linear regression using scikit-learn
X = data[['YR', 'AA', 'CCF', 'TPAM', 'SAGC']]
y = data['LSH']

model = LinearRegression()
model.fit(X, y)
coefficients = model.coef_
intercept = model.intercept_

# Step 4: Estimation using Python
predicted_values = model.predict(X)

# Step 5: Compare the Results
# You can calculate performance metrics or create visualizations to compare predicted values and actual values.

# Step 6: Bayesian Model and MCMC Estimation
with pm.Model() as bayesian_model:
    # Define priors for the model parameters
    # For simplicity, let's assume normal priors for the coefficients and a half-normal prior for the intercept
    intercept_prior = pm.HalfNormal('intercept_prior', sd=10)
    coefficients_prior = pm.Normal('coefficients_prior', mu=0, sd=10, shape=5)
    
    # Define the likelihood function
    likelihood = pm.Normal('likelihood', mu=intercept_prior + pm.math.dot(X, coefficients_prior), sd=1, observed=y)
    
    # Perform MCMC sampling
    trace = pm.sample(2000, tune=1000)
    
# Step 7: Interpretation of Results
# You can analyze the posterior distribution using various visualization techniques provided by PyMC3

pm.traceplot(trace)
plt.show()

# %%
pip install pymc3
# Out:
# ...
#   Using cached pymc3-3.11.5-py3-none-any.whl (872 kB)
# ...
#   Using cached deprecat-2.1.1-py2.py3-none-any.whl (9.8 kB)
# ...
#      -------------------------------------- 34.3/34.3 MB 196.8 kB/s eta 0:00:00
# ...
#   Using cached Theano-PyMC-1.1.2.tar.gz (1.8 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached fastprogress-1.0.3-py3-none-any.whl (12 kB)
# ...
#   Using cached semver-3.0.1-py3-none-any.whl (17 kB)
# ...
#   Using cached arviz-0.15.1-py3-none-any.whl (1.6 MB)
# ...
#      -------------------------------------- 43.3/43.3 kB 124.2 kB/s eta 0:00:00
# ...
#   Using cached xarray-2023.5.0-py3-none-any.whl (994 kB)
# ...
#   Using cached xarray_einstats-0.5.1-py3-none-any.whl (28 kB)
# ...
#   Using cached arviz-0.15.0-py3-none-any.whl (1.6 MB)
#   Using cached arviz-0.14.0-py3-none-any.whl (1.7 MB)
# ...
#      ---------------------------------------- 6.6/6.6 MB 181.2 kB/s eta 0:00:00
# ...
#   Using cached arviz-0.13.0-py3-none-any.whl (1.7 MB)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import pymc3 as pm
import arviz as az

# Step 1: Data Cleaning and Visualization
data = pd.read_excel("C:/Users/This PC/Downloads/data.xlsx")
data = data.iloc[:-1]  # Remove the last row

# Scatter plot of LSH vs other variables
variables = ["YR", "AA", "CCF", "TPAM", "SAGC"]
for variable in variables:
    plt.scatter(data["LSH"], data[variable], label=variable)

plt.xlabel("LSH")
plt.ylabel("Variables")
plt.legend()
plt.show()

# Step 2: Likelihood Function or Loss Function
# Define your likelihood function or loss function based on your problem

# Step 3: Estimation of Model Parameters and Optimization
# Choose and fit your model using a suitable technique

# Step 4: Estimation using Python (Example using linear regression)
from sklearn.linear_model import LinearRegression

X = data[variables]
y = data["LSH"]

model = LinearRegression()
model.fit(X, y)

# Step 5: Compare the Results
# Example: Comparing actual and predicted values
y_pred = model.predict(X)

plt.scatter(y, y_pred)
plt.xlabel("Actual LSH")
plt.ylabel("Predicted LSH")
plt.show()

# Step 6: Bayesian Model and MCMC Estimation
with pm.Model() as bayesian_model:
    # Define priors for model parameters
    # Example using normal priors
    intercept = pm.Normal("intercept", mu=0, sigma=10)
    coefficients = pm.Normal("coefficients", mu=0, sigma=10, shape=len(variables))
    
    # Define likelihood (or loss function) based on the model structure
    mu = intercept + pm.math.dot(X, coefficients)
    sigma = pm.HalfNormal("sigma", sigma=10)
    likelihood = pm.Normal("likelihood", mu=mu, sigma=sigma, observed=y)
    
    # Perform MCMC sampling
    trace = pm.sample(1000, tune=1000)
    posterior_predictive = pm.sample_posterior_predictive(trace)
    
# Step 7: Interpretation of Results
# Example: Plotting posterior distributions
az.plot_trace(trace)
plt.show()

# Example: Plotting posterior predictive checks
az.plot_ppc(posterior_predictive, data={"likelihood": y})
plt.show()

# Example: Summary statistics of posterior distributions
az.summary(trace)
# Out:
# C:\Users\This PC\anaconda3\lib\site-packages\deprecat\classic.py:215: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   return wrapped_(*args_, **kwargs_)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# C:\Users\This PC\anaconda3\lib\site-packages\theano\tensor\elemwise.py:826: RuntimeWarning: divide by zero encountered in log
#   variables = ufunc(*ufunc_args, **ufunc_kwargs)
# C:\Users\This PC\anaconda3\lib\site-packages\theano\tensor\elemwise.py:826: RuntimeWarning: invalid value encountered in multiply
#   variables = ufunc(*ufunc_args, **ufunc_kwargs)
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [sigma, coefficients, intercept]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import pymc3 as pm
import arviz as az

# Step 1: Data Cleaning and Visualization
data = pd.read_excel("C:/Users/This PC/Downloads/data.xlsx")
data = data.iloc[:-1]  # Remove the last row

# Scatter plot of LSH vs other variables
variables = ["YR", "AA", "CCF", "TPAM", "SAGC"]
for variable in variables:
    plt.scatter(data["LSH"], data[variable], label=variable)

plt.xlabel("LSH")
plt.ylabel("Variables")
plt.legend()
plt.show()

# Step 2: Likelihood Function or Loss Function
# Define your likelihood function or loss function based on your problem

# Step 3: Estimation of Model Parameters and Optimization
# Choose and fit your model using a suitable technique

# Step 4: Estimation using Python (Example using linear regression)
from sklearn.linear_model import LinearRegression

X = data[variables]
y = data["LSH"]

model = LinearRegression()
model.fit(X, y)

# Step 5: Compare the Results
# Example: Comparing actual and predicted values
y_pred = model.predict(X)

plt.scatter(y, y_pred)
plt.xlabel("Actual LSH")
plt.ylabel("Predicted LSH")
plt.show()

# Step 6: Bayesian Model and MCMC Estimation
with pm.Model() as bayesian_model:
    # Define priors for model parameters
    # Example using normal priors
    intercept = pm.Normal("intercept", mu=0, sigma=10)
    coefficients = pm.Normal("coefficients", mu=0, sigma=10, shape=len(variables))
    
    # Define likelihood (or loss function) based on the model structure
    mu = intercept + pm.math.dot(X, coefficients)
    sigma = pm.HalfNormal("sigma", sigma=10)
    likelihood = pm.Normal("likelihood", mu=mu, sigma=sigma, observed=y)
    
    # Perform MCMC sampling with NUTS algorithm
    trace = pm.sample(1000, tune=1000, step=pm.NUTS())
    posterior_predictive = pm.sample_posterior_predictive(trace)
    
# Step 7: Interpretation of Results
# Example: Plotting posterior distributions
az.plot_trace(trace)
plt.show()

# Example: Plotting posterior predictive checks
az.plot_ppc(posterior_predictive, data={"likelihood": y})
plt.show()

# Example: Summary statistics of posterior distributions
az.summary(trace)
# Out:
# C:\Users\This PC\anaconda3\lib\site-packages\theano\tensor\elemwise.py:826: RuntimeWarning: divide by zero encountered in log
#   variables = ufunc(*ufunc_args, **ufunc_kwargs)
# C:\Users\This PC\anaconda3\lib\site-packages\theano\tensor\elemwise.py:826: RuntimeWarning: invalid value encountered in multiply
#   variables = ufunc(*ufunc_args, **ufunc_kwargs)
# C:\Users\This PC\anaconda3\lib\site-packages\deprecat\classic.py:215: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   return wrapped_(*args_, **kwargs_)
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [sigma, coefficients, intercept]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import pymc3 as pm

# Step 1: Data Cleaning and Visualization
# Load the dataset
data = pd.read_excel('C:/Users/This PC/Downloads/data.xlsx')

# Remove the last row
data = data[:-1]

# Visualize the relationship between LSH and the other variables
fig, axs = plt.subplots(2, 2, figsize=(10, 8))
axs[0, 0].scatter(data['LSH'], data['YR'])
axs[0, 0].set_xlabel('LSH')
axs[0, 0].set_ylabel('YR')
axs[0, 1].scatter(data['LSH'], data['AA'])
axs[0, 1].set_xlabel('LSH')
axs[0, 1].set_ylabel('AA')
axs[1, 0].scatter(data['LSH'], data['CCF'])
axs[1, 0].set_xlabel('LSH')
axs[1, 0].set_ylabel('CCF')
axs[1, 1].scatter(data['LSH'], data['TPAM'])
axs[1, 1].set_xlabel('LSH')
axs[1, 1].set_ylabel('TPAM')
plt.tight_layout()
plt.show()

# Step 2: Likelihood Function or Loss Function (Depends on the specific problem)

# Step 3: Estimation of Model Parameters and Optimization
# Fit a linear regression model to the data
X = data[['YR', 'AA', 'CCF', 'TPAM']]
y = data['LSH']
model = LinearRegression()
model.fit(X, y)

# Step 4: Estimation using Python
# Make predictions using the trained model
predictions = model.predict(X)

# Step 5: Compare the Results
# Compare the predicted values with the actual values
comparison = pd.DataFrame({'Actual LSH': y, 'Predicted LSH': predictions})
print(comparison)

# Step 6: Bayesian Model and MCMC Estimation
with pm.Model() as bayesian_model:
    # Define priors for the model parameters
    # (You would need to specify appropriate priors based on your problem)
    alpha = pm.Normal('alpha', mu=0, sd=10)
    beta = pm.Normal('beta', mu=0, sd=10, shape=4)
    sigma = pm.HalfNormal('sigma', sd=1)

    # Define the likelihood function
    likelihood = pm.Normal('LSH', mu=alpha + pm.math.dot(X, beta), sd=sigma, observed=y)

    # Run MCMC sampling
    trace = pm.sample(1000, tune=1000)

# Step 7: Interpretation of Results
# Plot posterior distributions and other diagnostic plots
pm.traceplot(trace)
plt.show()
# Out:
#     Actual LSH  Predicted LSH
# 0     37911.00   38741.476756
# 1     39151.20   39031.379910
# 2     40473.30   41124.390078
# 3     39408.00   40200.781068
# 4     40754.90   40866.462140
# 5     44624.00   44968.659890
# 6     43529.00   41277.718755
# 7     44266.00   42954.079872
# 8     45649.00   45139.947518
# 9     44510.00   42053.163050
# 10    46662.00   47262.972475
# 11    50454.00   48608.991048
# 12    49417.00   44986.474212
# 13    51230.00   47907.847760
# 14    50839.00   47537.091896
# 15    46218.00   44304.574124
# 16    45264.00   46096.714798
# 17    45706.00   48713.475952
# 18    43069.50   46817.794913
# 19    46946.90   55124.849682
# 20    48402.20   53901.011354
# 21    49804.20   52298.337202
# 22    50160.30   52713.044647
# 23    53434.29   54399.004403
# 24    53940.86   55371.276532
# 25    55911.31   57093.591032
# 26    58849.33   60403.071720
# 27    61222.62   61314.827795
# 28    63048.20   60617.018935
# 29    63964.83   61783.931578
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import pymc3 as pm
import arviz as az

# Step 1: Data Cleaning and Visualization
data = pd.read_excel('C:/Users/This PC/Downloads/data.xlsx')
data = data[:-1]

fig, axs = plt.subplots(2, 2, figsize=(10, 8))
axs[0, 0].scatter(data['LSH'], data['YR'])
axs[0, 0].set_xlabel('LSH')
axs[0, 0].set_ylabel('YR')
axs[0, 1].scatter(data['LSH'], data['AA'])
axs[0, 1].set_xlabel('LSH')
axs[0, 1].set_ylabel('AA')
axs[1, 0].scatter(data['LSH'], data['CCF'])
axs[1, 0].set_xlabel('LSH')
axs[1, 0].set_ylabel('CCF')
axs[1, 1].scatter(data['LSH'], data['TPAM'])
axs[1, 1].set_xlabel('LSH')
axs[1, 1].set_ylabel('TPAM')
plt.tight_layout()
plt.show()

# Step 2: Likelihood Function or Loss Function (Depends on the specific problem)

# Step 3: Estimation of Model Parameters and Optimization
X = data[['YR', 'AA', 'CCF', 'TPAM']]
y = data['LSH']
model = LinearRegression()
model.fit(X, y)

# Step 4: Estimation using Python
predictions = model.predict(X)

# Step 5: Compare the Results
comparison = pd.DataFrame({'Actual LSH': y, 'Predicted LSH': predictions})
print(comparison)

# Step 6: Bayesian Model and MCMC Estimation
with pm.Model() as bayesian_model:
    alpha = pm.Normal('alpha', mu=0, sd=10)
    beta = pm.Normal('beta', mu=0, sd=10, shape=4)
    sigma = pm.HalfNormal('sigma', sd=1)

    likelihood = pm.Normal('LSH', mu=alpha + pm.math.dot(X, beta), sd=sigma, observed=y)

    trace = pm.sample(1000, tune=1000, return_inferencedata=True)

# Step 7: Interpretation of Results
az.plot_trace(trace)
plt.show()
# Out:
#     Actual LSH  Predicted LSH
# 0     37911.00   38741.476756
# 1     39151.20   39031.379910
# 2     40473.30   41124.390078
# 3     39408.00   40200.781068
# 4     40754.90   40866.462140
# 5     44624.00   44968.659890
# 6     43529.00   41277.718755
# 7     44266.00   42954.079872
# 8     45649.00   45139.947518
# 9     44510.00   42053.163050
# 10    46662.00   47262.972475
# 11    50454.00   48608.991048
# 12    49417.00   44986.474212
# 13    51230.00   47907.847760
# 14    50839.00   47537.091896
# 15    46218.00   44304.574124
# 16    45264.00   46096.714798
# 17    45706.00   48713.475952
# 18    43069.50   46817.794913
# 19    46946.90   55124.849682
# 20    48402.20   53901.011354
# 21    49804.20   52298.337202
# 22    50160.30   52713.044647
# 23    53434.29   54399.004403
# 24    53940.86   55371.276532
# 25    55911.31   57093.591032
# 26    58849.33   60403.071720
# 27    61222.62   61314.827795
# 28    63048.20   60617.018935
# 29    63964.83   61783.931578
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import pymc3 as pm
import arviz as az

# Step 1: Data Cleaning and Visualization
data = pd.read_excel(r'C:\Users\This PC\Downloads\data.xlsx')
data = data.iloc[:-1]  # Remove the last row

# Visualize the relationship between LSH and the other four variables
plt.scatter(data['LSH'], data['YR'], label='YR')
plt.scatter(data['LSH'], data['AA'], label='AA')
plt.scatter(data['LSH'], data['CCF'], label='CCF')
plt.scatter(data['LSH'], data['TPAM'], label='TPAM')
plt.scatter(data['LSH'], data['SAGC'], label='SAGC')
plt.xlabel('LSH')
plt.ylabel('Variables')
plt.legend()
plt.show()

# Step 2: Likelihood Function or Loss Function
# Define your likelihood function or loss function based on your specific problem

# Step 3: Estimation of Model Parameters and Optimization
# Choose a modeling technique and optimize the model parameters

# Step 4: Estimation using Python (e.g., linear regression using scikit-learn)
from sklearn.linear_model import LinearRegression

X = data[['AA', 'CCF', 'TPAM', 'SAGC']]
y = data['LSH']

model = LinearRegression()
model.fit(X, y)

# Step 5: Compare the Results

# Compare the predicted values with the actual values
predicted = model.predict(X)

plt.scatter(data['LSH'], predicted)
plt.xlabel('LSH (Actual)')
plt.ylabel('LSH (Predicted)')
plt.show()

# Step 6: Bayesian Model and MCMC Estimation
with pm.Model() as bayesian_model:
    # Define priors for the model parameters
    # ...

    # Define the likelihood function
    # ...

    # Run the MCMC sampling
    trace = pm.sample(2000, tune=1000)

# Step 7: Interpretation of Results
# Visualize the posterior distribution of the model parameters
az.plot_trace(trace)
plt.show()

# Analyze the posterior distribution and derive conclusions
# ...
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20260\3109585477.py in <module>
#      53
#      54     # Run the MCMC sampling
# ---> 55     trace = pm.sample(2000, tune=1000)
#      56
#      57 # Step 7: Interpretation of Results
#
# ~\anaconda3\lib\site-packages\deprecat\classic.py in wrapper_function(wrapped_, instance_, args_, kwargs_)
#     213                         else:
#     214                             warnings.warn(message, category=category, stacklevel=_routine_stacklevel)
# --> 215                 return wrapped_(*args_, **kwargs_)
#     216
#     217             return wrapper_function(wrapped)
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import pymc3 as pm
import arviz as az

# Step 1: Data Cleaning and Visualization
data = pd.read_excel(r'C:\Users\This PC\Downloads\data.xlsx')
data = data.iloc[:-1]  # Remove the last row

# Visualize the relationship between LSH and the other four variables
plt.scatter(data['LSH'], data['YR'], label='YR')
plt.scatter(data['LSH'], data['AA'], label='AA')
plt.scatter(data['LSH'], data['CCF'], label='CCF')
plt.scatter(data['LSH'], data['TPAM'], label='TPAM')
plt.scatter(data['LSH'], data['SAGC'], label='SAGC')
plt.xlabel('LSH')
plt.ylabel('Variables')
plt.legend()
plt.show()

# Step 2: Likelihood Function or Loss Function
# Define your likelihood function or loss function based on your specific problem

# Step 3: Estimation of Model Parameters and Optimization
# Choose a modeling technique and optimize the model parameters

# Step 4: Estimation using Python (e.g., linear regression using scikit-learn)
from sklearn.linear_model import LinearRegression

X = data[['AA', 'CCF', 'TPAM', 'SAGC']]
y = data['LSH']

model = LinearRegression()
model.fit(X, y)

# Step 5: Compare the Results

# Compare the predicted values with the actual values
predicted = model.predict(X)

plt.scatter(data['LSH'], predicted)
plt.xlabel('LSH (Actual)')
plt.ylabel('LSH (Predicted)')
plt.show()

# Step 6: Bayesian Model and MCMC Estimation
with pm.Model() as bayesian_model:
    # Define priors for the model parameters
    # ...

    # Define the likelihood function
    # ...

    # Run the MCMC sampling
    trace = pm.sample(2000, tune=1000, cores=1, start=model.named_steps['linearregression'].coef_)

# Step 7: Interpretation of Results
# Visualize the posterior distribution of the model parameters
az.plot_trace(trace)
plt.show()

# Analyze the posterior distribution and derive conclusions
# ...
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20260\1325235554.py in <module>
#      53
#      54     # Run the MCMC sampling
# ---> 55     trace = pm.sample(2000, tune=1000, cores=1, start=model.named_steps['linearregression'].coef_)
#      56
#      57 # Step 7: Interpretation of Results
#
# AttributeError: 'LinearRegression' object has no attribute 'named_steps'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import pymc3 as pm
import arviz as az

# Step 1: Data Cleaning and Visualization
data = pd.read_excel(r'C:\Users\This PC\Downloads\data.xlsx')
data = data.iloc[:-1]  # Remove the last row

# Visualize the relationship between LSH and the other four variables
plt.scatter(data['LSH'], data['YR'], label='YR')
plt.scatter(data['LSH'], data['AA'], label='AA')
plt.scatter(data['LSH'], data['CCF'], label='CCF')
plt.scatter(data['LSH'], data['TPAM'], label='TPAM')
plt.scatter(data['LSH'], data['SAGC'], label='SAGC')
plt.xlabel('LSH')
plt.ylabel('Variables')
plt.legend()
plt.show()

# Step 2: Likelihood Function or Loss Function
# Define your likelihood function or loss function based on your specific problem

# Step 3: Estimation of Model Parameters and Optimization
# Choose a modeling technique and optimize the model parameters

# Step 4: Estimation using Python (e.g., linear regression using scikit-learn)
from sklearn.linear_model import LinearRegression

X = data[['AA', 'CCF', 'TPAM', 'SAGC']]
y = data['LSH']

model = LinearRegression()
model.fit(X, y)

# Step 5: Compare the Results

# Compare the predicted values with the actual values
predicted = model.predict(X)

plt.scatter(data['LSH'], predicted)
plt.xlabel('LSH (Actual)')
plt.ylabel('LSH (Predicted)')
plt.show()

# Step 6: Bayesian Model and MCMC Estimation
with pm.Model() as bayesian_model:
    # Define priors for the model parameters
    # ...

    # Define the likelihood function
    # ...

    # Run the MCMC sampling
    trace = pm.sample(2000, tune=1000, cores=1, start=model.coef_)

# Step 7: Interpretation of Results
# Visualize the posterior distribution of the model parameters
az.plot_trace(trace)
plt.show()

# Analyze the posterior distribution and derive conclusions
# ...
# Out:
# C:\Users\This PC\AppData\Local\Temp\ipykernel_20260\3229637903.py:55: DeprecationWarning: Call to deprecated Parameter start. (renamed to `initvals` in PyMC v4.0.0) -- Deprecated since v3.11.5.
#   trace = pm.sample(2000, tune=1000, cores=1, start=model.coef_)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20260\3229637903.py in <module>
#      53
#      54     # Run the MCMC sampling
# ---> 55     trace = pm.sample(2000, tune=1000, cores=1, start=model.coef_)
#      56
#      57 # Step 7: Interpretation of Results
#
# ~\anaconda3\lib\site-packages\deprecat\classic.py in wrapper_function(wrapped_, instance_, args_, kwargs_)
#     213                         else:
#     214                             warnings.warn(message, category=category, stacklevel=_routine_stacklevel)
# --> 215                 return wrapped_(*args_, **kwargs_)
#     216
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import pymc3 as pm

# Step 1: Data Cleaning and Visualization
data = pd.read_excel('C://Users//This PC//Downloads//data.xlsx')
data = data.drop(data.index[-1])  # Remove the last row

# Scatter plots to visualize the relationship between LSH and other variables
fig, axs = plt.subplots(2, 2, figsize=(10, 8))
axs[0, 0].scatter(data['LSH'], data['YR'])
axs[0, 0].set_xlabel('LSH')
axs[0, 0].set_ylabel('YR')

axs[0, 1].scatter(data['LSH'], data['AA'])
axs[0, 1].set_xlabel('LSH')
axs[0, 1].set_ylabel('AA')

axs[1, 0].scatter(data['LSH'], data['CCF'])
axs[1, 0].set_xlabel('LSH')
axs[1, 0].set_ylabel('CCF')

axs[1, 1].scatter(data['LSH'], data['TPAM'])
axs[1, 1].set_xlabel('LSH')
axs[1, 1].set_ylabel('TPAM')

plt.tight_layout()
plt.show()

# Step 2: Likelihood Function or Loss Function
# Define the specific likelihood or loss function based on your modeling approach.

# Step 3: Estimation of Model Parameters and Optimization
# For this example, let's perform linear regression using scikit-learn
X = data[['YR', 'AA', 'CCF', 'TPAM', 'SAGC']]
y = data['LSH']

model = LinearRegression()
model.fit(X, y)
coefficients = model.coef_
intercept = model.intercept_

# Step 4: Estimation using Python
predicted_values = model.predict(X)

# Step 5: Compare the Results
# You can calculate performance metrics or create visualizations to compare predicted values and actual values.

# Step 6: Bayesian Model and MCMC Estimation
with pm.Model() as bayesian_model:
    # Define priors for the model parameters
    # For simplicity, let's assume normal priors for the coefficients and a half-normal prior for the intercept
    intercept_prior = pm.HalfNormal('intercept_prior', sd=10)
    coefficients_prior = pm.Normal('coefficients_prior', mu=0, sd=10, shape=5)
    
    # Define the likelihood function
    likelihood = pm.Normal('likelihood', mu=intercept_prior + pm.math.dot(X, coefficients_prior), sd=1, observed=y)
    
    # Perform MCMC sampling
    trace = pm.sample(2000, tune=1000)
    
# Step 7: Interpretation of Results
# You can analyze the posterior distribution using various visualization techniques provided by PyMC3

pm.traceplot(trace)
plt.show()
# Out:
# C:\Users\This PC\anaconda3\lib\site-packages\deprecat\classic.py:215: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   return wrapped_(*args_, **kwargs_)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# C:\Users\This PC\anaconda3\lib\site-packages\theano\tensor\elemwise.py:826: RuntimeWarning: divide by zero encountered in log
#   variables = ufunc(*ufunc_args, **ufunc_kwargs)
# C:\Users\This PC\anaconda3\lib\site-packages\theano\tensor\elemwise.py:826: RuntimeWarning: invalid value encountered in multiply
#   variables = ufunc(*ufunc_args, **ufunc_kwargs)
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [coefficients_prior, intercept_prior]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import pymc3 as pm

# Step 1: Data Cleaning and Visualization
data = pd.read_excel("C:/Users/This PC/Downloads/data.xlsx")
data = data.iloc[:-1]  # Remove the last row

# Scatter plot of LSH against other variables
plt.figure(figsize=(12, 6))
variables = ["YR", "AA", "CCF", "TPAM", "SAGC"]
for var in variables:
    plt.scatter(data["LSH"], data[var], label=var)
plt.xlabel("LSH")
plt.ylabel("Variables")
plt.legend()
plt.show()

# Step 2: Likelihood Function or Loss Function
# Define your likelihood function or loss function based on your specific problem

# Step 3: Estimation of Model Parameters and Optimization
# Choose a suitable regression technique and estimate model parameters
# Here's an example using scikit-learn's linear regression
from sklearn.linear_model import LinearRegression

X = data[variables]
y = data["LSH"]

model = LinearRegression()
model.fit(X, y)
parameters = model.coef_
intercept = model.intercept_

# Step 4: Estimation using Python
# Make predictions using the fitted model
predictions = model.predict(X)

# Step 5: Compare the Results
# Compare predictions with actual values, calculate performance metrics, etc.

# Step 6: Bayesian Model and MCMC Estimation
# Define a Bayesian model and estimate with MCMC using PyMC3
with pm.Model() as bayesian_model:
    # Define priors
    alpha = pm.Normal("alpha", mu=0, sd=10)
    beta = pm.Normal("beta", mu=0, sd=10, shape=len(variables))
    
    # Define likelihood
    sigma = pm.HalfCauchy("sigma", beta=10)
    mu = alpha + pm.math.dot(X, beta)
    likelihood = pm.Normal("likelihood", mu=mu, sd=sigma, observed=y)
    
    # Perform MCMC sampling
    trace = pm.sample(2000, tune=1000, cores=1)
    
# Step 7: Interpretation of Results
# Analyze the trace plots, posterior distributions, etc. to interpret the results

# Example plot of posterior distributions
pm.plot_posterior(trace, var_names=["alpha", "beta"])
plt.show()
# Out:
# C:\Users\This PC\anaconda3\lib\site-packages\deprecat\classic.py:215: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   return wrapped_(*args_, **kwargs_)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# C:\Users\This PC\anaconda3\lib\site-packages\theano\tensor\elemwise.py:826: RuntimeWarning: divide by zero encountered in log
#   variables = ufunc(*ufunc_args, **ufunc_kwargs)
# C:\Users\This PC\anaconda3\lib\site-packages\theano\tensor\elemwise.py:826: RuntimeWarning: invalid value encountered in multiply
#   variables = ufunc(*ufunc_args, **ufunc_kwargs)
# Sequential sampling (2 chains in 1 job)
# NUTS: [sigma, beta, alpha]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import pymc3 as pm

# Step 1: Data Cleaning and Visualization
data = pd.read_excel("C:/Users/This PC/Downloads/data.xlsx")
data = data.iloc[:-1]  # Remove the last row

# Scatter plot of LSH against other variables
plt.figure(figsize=(12, 6))
variables = ["YR", "AA", "CCF", "TPAM", "SAGC"]
for var in variables:
    plt.scatter(data["LSH"], data[var], label=var)
plt.xlabel("LSH")
plt.ylabel("Variables")
plt.legend()
plt.show()

# Step 2: Likelihood Function or Loss Function
# Define your likelihood function or loss function based on your specific problem

# Step 3: Estimation of Model Parameters and Optimization
# Choose a suitable regression technique and estimate model parameters
# Here's an example using scikit-learn's linear regression
from sklearn.linear_model import LinearRegression

X = data[variables]
y = data["LSH"]

model = LinearRegression()
model.fit(X, y)
parameters = model.coef_
intercept = model.intercept_

# Step 4: Estimation using Python
# Make predictions using the fitted model
predictions = model.predict(X)

# Step 5: Compare the Results
# Compare predictions with actual values, calculate performance metrics, etc.

# Step 6: Bayesian Model and MCMC Estimation
# Define a Bayesian model and estimate with MCMC using PyMC3
with pm.Model() as bayesian_model:
    # Define priors
    alpha = pm.Normal("alpha", mu=0, sd=100)  # Wider prior for alpha
    beta = pm.Normal("beta", mu=0, sd=100, shape=len(variables))  # Wider prior for beta
    
    # Define likelihood
    sigma = pm.HalfCauchy("sigma", beta=10)
    mu = alpha + pm.math.dot(X, beta)
    likelihood = pm.Normal("likelihood", mu=mu, sd=sigma, observed=y)
    
    # Perform MCMC sampling
    trace = pm.sample(2000, tune=1000, cores=1)
    
# Step 7: Interpretation of Results
# Analyze the trace plots, posterior distributions, etc. to interpret the results

# Example plot of posterior distributions
pm.plot_posterior(trace, var_names=["alpha", "beta"])
plt.show()
# Out:
# C:\Users\This PC\anaconda3\lib\site-packages\deprecat\classic.py:215: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   return wrapped_(*args_, **kwargs_)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# C:\Users\This PC\anaconda3\lib\site-packages\theano\tensor\elemwise.py:826: RuntimeWarning: divide by zero encountered in log
#   variables = ufunc(*ufunc_args, **ufunc_kwargs)
# C:\Users\This PC\anaconda3\lib\site-packages\theano\tensor\elemwise.py:826: RuntimeWarning: invalid value encountered in multiply
#   variables = ufunc(*ufunc_args, **ufunc_kwargs)
# Sequential sampling (2 chains in 1 job)
# NUTS: [sigma, beta, alpha]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset from the Excel file
data = pd.read_excel(r'C:\Users\This PC\Downloads\data.xlsx')

# Remove the last row
data = data[:-1]

# Visualize the relationship between LSH and the other variables
plt.figure(figsize=(12, 6))
plt.scatter(data['LSH'], data['AA'], label='AA')
plt.scatter(data['LSH'], data['CCF'], label='CCF')
plt.scatter(data['LSH'], data['TPAM'], label='TPAM')
plt.scatter(data['LSH'], data['SAGC'], label='SAGC')
plt.xlabel('LSH')
plt.ylabel('Variables')
plt.legend()
plt.title('Relationship between LSH and other variables')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Read and clean the data
data = pd.read_excel('C:/Users/This PC/Downloads/data.xlsx')
data = data.iloc[:-1]  # Remove the last row

# Step 2: Visualize the relationship between LSH and the other variables
sns.pairplot(data, x_vars=['AA', 'CCF', 'TPAM', 'SAGC'], y_vars='LSH', kind='scatter')
plt.show()

# Step 3: Likelihood function or loss function is not provided in the given information

# Step 4: Estimation of model parameters using regression
from sklearn.linear_model import LinearRegression

X = data[['AA', 'CCF', 'TPAM', 'SAGC']]
y = data['LSH']

model = LinearRegression()
model.fit(X, y)

# Step 5: No other results are provided for comparison

# Step 6: Bayesian modeling with MCMC is not provided in the given information

# Step 7: Interpretation of results and visualization is not provided in the given information
# Out:
# LinearRegression()
